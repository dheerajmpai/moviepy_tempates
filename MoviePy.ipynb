# %%
import moviepy

# %%
# !nautilus ./

# %%
from moviepy.editor import VideoFileClip
my_clip = VideoFileClip('2.mp4')
print("Duration of video : ", my_clip.duration)
print("FPS : ", my_clip.fps)
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Duration of video :  15.02
# FPS :  29.97002997002997

# %%
new_clip = my_clip.subclip(2,7.0012)

# %%
print('new clip duration : ',new_clip.duration)
# Out:
# new clip duration :  5.0012

# %%
new_clip.write_videofile("new_clip.mov", codec = "libx264", fps=25)
# Out:
# [MoviePy] >>>> Building video new_clip.mov
# [MoviePy] Writing audio in new_clipTEMP_MPY_wvf_snd.mp3
# 100%|██████████| 111/111 [00:00<00:00, 639.04it/s]
# [MoviePy] Done.
# [MoviePy] Writing video new_clip.mov
# 100%|██████████| 126/126 [00:17<00:00,  7.36it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: new_clip.mov

# %%
new_clip.save_frame('hELLO.PNG')

# %%
cut_clip = new_clip.crop(1,1,500,500)

# %%
cut_clip.write_videofile("CutClip.mov",codec= "libx264", fps=25)
# Out:
# [MoviePy] >>>> Building video CutClip.mov
# [MoviePy] Writing audio in CutClipTEMP_MPY_wvf_snd.mp3
# 100%|██████████| 111/111 [00:00<00:00, 398.54it/s]
# [MoviePy] Done.
# [MoviePy] Writing video CutClip.mov
# 100%|██████████| 126/126 [00:04<00:00, 26.30it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: CutClip.mov

# %%
crossfade = new_clip.crossfadein(4)
crossfade.write_videofile("CrossFade.mov",codec= "libx264", fps=25)
# Out:
# [MoviePy] >>>> Building video CrossFade.mov
# [MoviePy] Writing audio in CrossFadeTEMP_MPY_wvf_snd.mp3
# 100%|██████████| 111/111 [00:00<00:00, 523.77it/s]
# [MoviePy] Done.
# [MoviePy] Writing video CrossFade.mov
# 100%|██████████| 126/126 [00:18<00:00,  6.83it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: CrossFade.mov

# %%
from moviepy.editor import VideoFileClip
my_clip = VideoFileClip('2.mp4')
print("Duration of video : ", my_clip.duration)
print("FPS : ", my_clip.fps)
gif_clip = my_clip.subclip()
# Out:
# Duration of video :  15.02
# FPS :  29.97002997002997

# %%
# gif_clip.write_gif('gif_clip_imagick.gif',fps=25,program= 'ffmpeg')

# %%
speed10x = my_clip.speedx(2.5)

# %%
speed10x.write_videofile("Speed10x.mov",codec= "libx264", fps=25)
# Out:
# [MoviePy] >>>> Building video Speed10x.mov
# [MoviePy] Writing audio in Speed10xTEMP_MPY_wvf_snd.mp3
# 100%|██████████| 133/133 [00:00<00:00, 551.26it/s]
# [MoviePy] Done.
# [MoviePy] Writing video Speed10x.mov
# 100%|██████████| 151/151 [00:21<00:00,  6.88it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: Speed10x.mov

# %% [markdown]
# ## Extracting Audio from a mp4 file

# %%
kadam = VideoFileClip('Kadam.mp4')
kadam.audio.write_audiofile('hellp.mp3')
# speed10x.add_mask?
# Out:
# [MoviePy] Writing audio in hellp.mp3
# 100%|██████████| 3880/3880 [00:06<00:00, 577.75it/s]
# [MoviePy] Done.

# %%
from moviepy.editor import *
import moviepy.video.fx.all as vfx

# %%
clip = VideoFileClip('walk.mp4')
clip = clip.resize(0.4)
sub = clip.subclip(0,2)
sub = sub.fx(vfx.crop, x1=115, x2=399, y1=0, y2=288)
clip2 = sub.speedx(final_duration=2)
clip3 = clip2.fx(vfx.time_mirror)
final = concatenate_videoclips([clip2, clip3])
final.to_gif("boomerang_like_gif.gif", fps=25)

# %%
from moviepy.editor import ipython_display
ipython_display('walk.mp4',maxduration=176.0)

# %%
accel = vfx.accel_decel(clip)

# %%
accel.write_videofile("accelwalk.mov",codec= "libx264", fps=25)
# Out:
# [MoviePy] >>>> Building video accelwalk.mov
# [MoviePy] Writing video accelwalk.mov
# ...
# 100%|█████████▉| 393/394 [00:27<00:00, 14.29it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: accelwalk.mov

# %%
accel = vfx.accel_decel(clip,new_duration=None, abruptness=1.0, soonness=1.0)
accel.duration, accel.write_videofile("accel.mov",codec= "libx264", fps=25)
# Out:
# [MoviePy] >>>> Building video accel.mov
# [MoviePy] Writing audio in accelTEMP_MPY_wvf_snd.mp3
# ...
# 100%|██████████| 332/332 [00:00<00:00, 798.55it/s][A
# [MoviePy] Done.
# [MoviePy] Writing video accel.mov
# ...
# 100%|██████████| 376/376 [00:22<00:00, 16.39it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: accel.mov
# (15.02, None)

# %%
# ~/anaconda3/lib/python3.6/site-packages/moviepy/video/io/VideoFileClip.py
from moviepy.video.io.VideoFileClip import VideoFileClip
VideoFileClip?

# %%
import moviepy.editor?

# %%
import moviepy.editor

# %%
# VideoFileClip?
